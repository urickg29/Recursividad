# %%
def fibonacci(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)

n = int(input(' Introde un numero entero: '))
print(fibonacci(n))

# %%
def sumar_lista(lista):
    if len(lista) == 0:
        return 0
    if  len(lista) == 1:
        return lista[0]
    else:
        return lista[0] + sumar_lista(lista[1:])

numeros = [] #INGRESAR LA LISTA DE NUMEROS AQUI
resultado = sumar_lista(numeros)
print('La suma de la lista es %i' % resultado)

# %%
def contador(num):

    print (num)
    if num == 0:
        return 'BOOMMMMM !!!'
    else:
        return contador (num-1)

num=int(input('Ingresa el numero maximo del contador'))
print (contador(num))

# %%
numero = int(input('Cuantos elementos tiene la lista: '))
if numero <= 1:
    print('Error')
else:
        lista = []
        for i in range(numero):
            num2 = input(f'Dime el numero {i + 1}:')
            lista += [num2]
print(f'La lista inicial dada es: {lista}')
if numero % 2 == 0:
    mitad = (numero/2)-1
    lista.pop(int(mitad))
    print(f'La lista con el caracter de la mitad eliminado es: {lista}')
else:
        mitad = numero/2
        lista.pop(int(mitad))
        print(f'La lista con el caracter de la mitad eliminado es: {lista}')
# Out:
# Cuantos elementos tiene la lista: 3
# Dime el numero 1:1
# Dime el numero 2:2
# Dime el numero 3:3
# La lista inicial dada es: ['1', '2', '3']
# La lista con el caracter de la mitad eliminado es: ['1', '3']
